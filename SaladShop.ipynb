# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# <a class="anchor" id="introduction"></a>
# ## Introduction: Business Problem
# This project will help solve the problem of where to open a salad shop in the borough of Manhattan in New York City. I will use Foursquare's location data to find out where salad shops are currently located. I will then use a JSON file containing data about the boundaries of neighborhoods to figure out which neighborhoods might have more salad eaters than salad shops. This project would be of interest to the stakeholders of a salad chain such as Chopt, as well as to small business owners who are researching where to open a new location.

# %% [markdown]
# <a class="anchor" id="data"></a>
# ##Data
# The first piece of data that I will need is the latitudinal and longitudinal coordinates of Manhattan, New York. To get this, I will use the module Nominatim from the geopy.geocoders package. I will search Manhattan, New York as an input and will get the latitude and longitude coordinates of Manhattan in return. I will set the returned values to the variables manhattan_latitude and manhattan_longitude, respectively. These variables will be used for the entirety of the project as the central location data.
#
# I will then be using the Foursquare API to pull data regarding existing salad shops around Manhattan. The Foursquare API will return a dataframe containing the names, addresses, latitudes and longitudes of salad places in the area.
#
# Finally, I will be using a JSON file containing geospatial data on the boundaries of Manhattan's neighborhoods. I will then use the folium package to visualize which neighborhoods and areas are might benefit from a salad shop.

# %% [markdown]
# ##Methodology
#
# First, I will use the latitude and longitude of Manhattan, as well as the category ID of salad places to access the Foursquare API.
#
# Next, I will clean the dataframe from Foursquare to make it easier to work with. I will then use the folium package to plot the locations of each of the salad shops in our dataframe.
#
# I will then import the JSON file for Manhattan neighborhoods and use it to generate a heat map showing the neighborhoods that have the highest and lowest amount of salad shops. I will then conduct exploratory data analysis to figure out which zip codes in which neighborhoods have the fewest salad shops.

# %% [markdown]
# Import necessary libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# Set necessary inputs to access the Foursquare API

# %%
CLIENT_ID = 'QEF4SFROUUVOQKNPAFNNRDUW4ACAWSYYG312LM3BKEDDKPIZ' # your Foursquare ID
CLIENT_SECRET = 'CCBFW1WDVTUYDLPFX3SR0QBB5R2UKRYOZ3F1JDJ3PLQMPDRM' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 50
CATEGORYID = '4bf58dd8d48988d1bd941735'
#search_query =
#radius =

# %%
address = 'Manhattan, NY'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
manhattan_latitude = location.latitude
manhattan_longitude = location.longitude
print(manhattan_latitude, manhattan_longitude)
# Out:
# 40.7896239 -73.9598939

# %% [markdown]
# Call the Foursquare API for a list of salad eateries in Manhattan

# %%
#url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT,CATEGORYID)
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&limit={}&categoryId={}'.format(CLIENT_ID, CLIENT_SECRET, manhattan_latitude, manhattan_longitude, VERSION, LIMIT,CATEGORYID)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=QEF4SFROUUVOQKNPAFNNRDUW4ACAWSYYG312LM3BKEDDKPIZ&client_secret=CCBFW1WDVTUYDLPFX3SR0QBB5R2UKRYOZ3F1JDJ3PLQMPDRM&ll=40.7896239,-73.9598939&v=20180604&limit=100&categoryId=4bf58dd8d48988d1bd941735'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
salad_dataframe = json_normalize(venues)
salad_dataframe.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id        name  ... venuePage.id location.neighborhood
# 0  5961782bf5e9d7031dd38a93  sweetgreen  ...          NaN                   NaN
# 1  5f3c5b789b9e3e7dcb3b7673  sweetgreen  ...          NaN                   NaN
# 2  5e1a0a999ab34d00087e4eb6  sweetgreen  ...          NaN                   NaN
# 3  5d66a35c927f8b0008a59e2b  sweetgreen  ...          NaN                   NaN
# 4  5b181bcad1a402002cce93ef  Fresh & Co  ...          NaN                   NaN
#
# [5 rows x 25 columns]

# %%
print(salad_dataframe.shape)
# Out:
# (50, 25)

# %% [markdown]
# Clean up the dataframe

# %%
salad_joints=salad_dataframe[['name','location.formattedAddress','location.lat','location.lng','location.postalCode']]
salad_joints.columns = ['Name', 'Address', 'Latitude', 'Longitude', 'Zip Code']
salad_joints
# Out:
#                       Name  ... Zip Code
# 0               sweetgreen  ...    10025
# 1               sweetgreen  ...    10019
# 2               sweetgreen  ...    10003
# 3               sweetgreen  ...    10016
# 4               Fresh & Co  ...    10011
# 5               sweetgreen  ...    10016
# 6     Bagel Pub Park Slope  ...    11215
# 7                Bagel Pub  ...    11238
# 8         Napolini Express  ...    11553
# 9               sweetgreen  ...    10023
# 10              sweetgreen  ...    10014
# 11              Just Salad  ...    10016
# 12    Xe Máy Sandwich Shop  ...    10009
# 13              sweetgreen  ...    11201
# 14              Just Salad  ...    10019
# 15                   CHOPT  ...    10019
# 16              sweetgreen  ...    10001
# 17                    Taïm  ...    10014
# 18              sweetgreen  ...    11211
# 19              sweetgreen  ...    10065
# 20              sweetgreen  ...    11201
# 21              sweetgreen  ...    10003
# 22              sweetgreen  ...    10005
# 23                 Dig Inn  ...    10023
# 24              Casa Nomad  ...    10001
# 25                   CHOPT  ...    10012
# 26              sweetgreen  ...    10003
# 27              Just Salad  ...    10023
# 28                   CHOPT  ...    10005
# 29              sweetgreen  ...    10003
# 30                    CAVA  ...    10573
# 31              sweetgreen  ...    10036
# 32           Pret A Manger  ...    10019
# 33              sweetgreen  ...    10001
# 34                   CHOPT  ...    10010
# 35              sweetgreen  ...    10021
# 36              sweetgreen  ...    10014
# 37              sweetgreen  ...    10012
# 38  Brooklyn Crepe & Juice  ...    11217
# 39                  Create  ...    11105
# 40           Pret A Manger  ...    10019
# 41              Just Salad  ...    10011
# 42              sweetgreen  ...    10018
# 43              sweetgreen  ...    10025
# 44                   CHOPT  ...    10003
# 45              Just Salad  ...    10010
# 46              Just Salad  ...    10028
# 47                   CHOPT  ...    10075
# 48                   CHOPT  ...    10024
# 49              sweetgreen  ...    10028
#
# [50 rows x 5 columns]

# %%
salad_joints['Latitude']
# Out:
# 0     40.791490
# 1     40.765232
# 2     40.726361
# 3     40.744243
# 4     40.748508
# 5     40.746307
# 6     40.669526
# 7     40.672343
# 8     40.722067
# 9     40.780298
# 10    40.739183
# 11    40.749332
# 12    40.727435
# 13    40.689910
# 14    40.762149
# 15    40.761165
# 16    40.752706
# 17    40.735970
# 18    40.715804
# 19    40.763714
# 20    40.702812
# 21    40.738061
# 22    40.705626
# 23    40.774260
# 24    40.746338
# 25    40.722076
# 26    40.733965
# 27    40.777488
# 28    40.706239
# 29    40.729794
# 30    41.003402
# 31    40.754640
# 32    40.765468
# 33    40.744803
# 34    40.740738
# 35    40.767128
# 36    40.729992
# 37    40.721184
# 38    40.679066
# 39    40.776467
# 40    40.765453
# 41    40.741240
# 42    40.752502
# 43    40.807284
# 44    40.737216
# 45    40.740729
# 46    40.777037
# 47    40.773797
# 48    40.781358
# 49    40.778012
# Name: Latitude, dtype: float64

# %% [markdown]
# Map our locations

# %%
# create map of New York using latitude and longitude values
map_newyork = folium.Map(location=[manhattan_latitude, manhattan_longitude], zoom_start=10)

# add markers to map
for lat, lng in zip(salad_joints['Latitude'], salad_joints['Longitude']):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_newyork)  
    
map_newyork
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a72fec7cf960> in <module>()
#       1 # create map of New York using latitude and longitude values
# ----> 2 map_newyork = folium.Map(location=[manhattan_latitude, manhattan_longitude], zoom_start=10)
#       3
#       4 # add markers to map
#       5 for lat, lng in zip(salad_joints['Latitude'], salad_joints['Longitude']):
#
# NameError: name 'folium' is not defined

# %% [markdown]
# Import the JSON file containing New York's zip code boundaries

# %%
import json # library to handle JSON files
with open('/nyc_zip_code_tabulation_areas_polygons.geojson') as json_data:
    newyork_data = json.load(json_data)
newyork_data
# Out:
# {'features': [{'geometry': {'coordinates': [[[[-73.840759, 40.625364],
#        [-73.843062, 40.627933],
#        [-73.844219, 40.629957],
#        [-73.842498, 40.631778],
#        [-73.836267, 40.633592],
#        [-73.835921, 40.633354],
#        [-73.835506, 40.63264],
#        [-73.839544, 40.626779],
#        [-73.840688, 40.62723],
#        [-73.841587, 40.628103],
#        [-73.841813, 40.628011],
#        [-73.840845, 40.626662],
#        [-73.8401, 40.626436],
#        [-73.840759, 40.625364]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Brooklyn',
#     'cartodb_id': 173,
#     'cty_fips': '047',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/11693',
#     'objectid': 173,
#     'po_name': 'Far Rockaway',
#     'postalcode': '11693',
#     'shape_area': 3497515.77978,
#     'shape_leng': 9479.91727716,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.915441, 40.875591],
#        [-73.915087, 40.876496],
#        [-73.912399, 40.878105],
#        [-73.911605, 40.879206],
#        [-73.909635, 40.87881],
#        [-73.909281, 40.878036],
#        [-73.908186, 40.877393],
#        [-73.907439, 40.876406],
#        [-73.907173, 40.873488],
#        [-73.907247, 40.872974],
#        [-73.908186, 40.872548],
#        [-73.908729, 40.871683],
#        [-73.909532, 40.873022],
#        [-73.910819, 40.874096],
#        [-73.911672, 40.874489],
#        [-73.915441, 40.875591]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Manhattan',
#     'cartodb_id': 48,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10463',
#     'objectid': 48,
#     'po_name': 'Bronx',
#     'postalcode': '10463',
#     'shape_area': 3119701.91325,
#     'shape_leng': 7791.51712739,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.932131, 40.869451],
#        [-73.931277, 40.868844],
#        [-73.93453, 40.863198],
#        [-73.933789, 40.863072],
#        [-73.934841, 40.861458],
#        [-73.935244, 40.860124],
#        [-73.935673, 40.85963],
#        [-73.936552, 40.859095],
#        [-73.937689, 40.857652],
#        [-73.936576, 40.857351],
#        [-73.937953, 40.85557],
#        [-73.937788, 40.855374],
#        [-73.933557, 40.854142],
#        [-73.928151, 40.851863],
#        [-73.927696, 40.852488],
#        [-73.92707, 40.852181],
#        [-73.927036, 40.851617],
#        [-73.927597, 40.850514],
#        [-73.928877, 40.849394],
#        [-73.929727, 40.848178],
#        [-73.930621, 40.848481],
#        [-73.930884, 40.848119],
#        [-73.928481, 40.846983],
#        [-73.92983, 40.845045],
#        [-73.931491, 40.845738],
#        [-73.931503, 40.845296],
#        [-73.932406, 40.844838],
#        [-73.884059, 40.822666],
#        [-73.884247, 40.823046],
#        [-73.884137, 40.82321],
#        [-73.884399, 40.824987],
#        [-73.884327, 40.825928],
#        [-73.883305, 40.829157],
#        [-73.88348, 40.829611],
#        [-73.883927, 40.829928],
#        [-73.884, 40.830179],
#        [-73.883379, 40.832027],
#        [-73.882519, 40.832148],
#        [-73.881391, 40.833539],
#        [-73.880964, 40.835674],
#        [-73.880111, 40.837234]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Bronx',
#     'cartodb_id': 64,
#     'cty_fips': '005',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10472',
#     'objectid': 64,
#     'po_name': 'Bronx',
#     'postalcode': '10472',
#     'shape_area': 30963245.188,
#     'shape_leng': 27006.0424107,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.933823, 40.8195],
#        [-73.933812, 40.815639],
#        [-73.933925, 40.815563],
#        [-73.933969, 40.814539],
#        [-73.933855, 40.814242],
#        [-73.934339, 40.809615],
#        [-73.934095, 40.808617],
#        [-73.933256, 40.807238],
#        [-73.933795, 40.80701],
#        [-73.934352, 40.807549],
#        [-73.935105, 40.80754],
#        [-73.943172, 40.810942],
#        [-73.936232, 40.820436],
#        [-73.933823, 40.8195]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Manhattan',
#     'cartodb_id': 74,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10037',
#     'objectid': 74,
#     'po_name': 'New York',
#     'postalcode': '10037',
#     'shape_area': 7188980.95327,
#     'shape_leng': 12511.8967445,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.944598, 40.803228],
#        [-73.94922, 40.79691],
#        [-73.961078, 40.8018],
#        [-73.959827, 40.805435],
#        [-73.957949, 40.808053],
#        [-73.957154, 40.809587],
#        [-73.957295, 40.810154],
#        [-73.958272, 40.810629],
#        [-73.957809, 40.811265],
#        [-73.954967, 40.810065],
#        [-73.956345, 40.808173],
#        [-73.944598, 40.803228]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Manhattan',
#     'cartodb_id': 77,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10026',
#     'objectid': 77,
#     'po_name': 'New York',
#     'postalcode': '10026',
#     'shape_area': 11092681.4885,
#     'shape_leng': 15644.9251484,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.993544, 40.751453],
#        [-73.993195, 40.751924],
#        [-73.991153, 40.751083],
#        [-73.991502, 40.750615],
#        [-73.993544, 40.751453]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 229,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10119',
#     'objectid': 229,
#     'po_name': 'New York',
#     'postalcode': '10119',
#     'shape_area': 126392.973553,
#     'shape_leng': 1679.33368634,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.960252, 40.751602],
#        [-73.959302, 40.753279],
#        [-73.958441, 40.753927],
#        [-73.954096, 40.759009],
#        [-73.952118, 40.760849],
#        [-73.951628, 40.76169],
#        [-73.950156, 40.763471],
#        [-73.949052, 40.764273],
#        [-73.945912, 40.768212],
#        [-73.94519, 40.768761],
#        [-73.945149, 40.769113],
#        [-73.944684, 40.769817],
#        [-73.942141, 40.772025],
#        [-73.940807, 40.772415],
#        [-73.940287, 40.772931],
#        [-73.940075, 40.772917],
#        [-73.940282, 40.772299],
#        [-73.940226, 40.77083],
#        [-73.941141, 40.769399],
#        [-73.94283, 40.768322],
#        [-73.949432, 40.760549],
#        [-73.951778, 40.758403],
#        [-73.952884, 40.756715],
#        [-73.955195, 40.754775],
#        [-73.957944, 40.752082],
#        [-73.959022, 40.75139],
#        [-73.961218, 40.749487],
#        [-73.961572, 40.749407],
#        [-73.961542, 40.749849],
#        [-73.961204, 40.750208],
#        [-73.961012, 40.750785],
#        [-73.960252, 40.751602]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Manhattan',
#     'cartodb_id':
]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Manhattan',
#     'cartodb_id': 133,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10038',
#     'objectid': 133,
#     'po_name': 'New York',
#     'postalcode': '10038',
#     'shape_area': 7022760.6429,
#     'shape_leng': 12605.2624283,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.934803, 40.713373],
#        [-73.932284, 40.707752],
#        [-73.931174, 40.703765],
#        [-73.927588, 40.701763],
#        [-73.93052, 40.698772],
#        [-73.930769, 40.698911],
#        [-73.933247, 40.697856],
#        [-73.932268, 40.697315],
#        [-73.935223, 40.696987],
#        [-73.934797, 40.696737],
#        [-73.934134, 40.693354],
#        [-73.951757, 40.691329],
#        [-73.95337, 40.699405],
#        [-73.95702, 40.698974],
#        [-73.957457, 40.700823],
#        [-73.950286, 40.705459],
#        [-73.951116, 40.710957],
#        [-73.94086, 40.711932],
#        [-73.934803, 40.713373]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Brooklyn',
#     'cartodb_id': 134,
#     'cty_fips': '047',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/11206',
#     'objectid': 134,
#     'po_name': 'Brooklyn',
#     'postalcode': '11206',
#     'shape_area': 40680014.9528,
#     'shape_leng': 28571.3804909,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-74.01451, 40.705552],
#        [-74.014252, 40.706162],
#        [-74.013433, 40.705882],
#        [-74.013812, 40.705407],
#        [-74.01451, 40.705552]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 246,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10275',
#     'objectid': 246,
#     'po_name': 'New York',
#     'postalcode': '10275',
#     'shape_area': 48280.4150043,
#     'shape_leng': 885.361027718,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.97845, 40.759065],
#        [-73.977989, 40.75969],
#        [-73.976745, 40.759165],
#        [-73.9772, 40.758538],
#        [-73.97845, 40.759065]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Manhattan',
#     'cartodb_id': 205,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10111',
#     'objectid': 205,
#     'po_name': 'New York',
#     'postalcode': '10111',
#     'shape_area': 103066.25326,
#     'shape_leng': 1311.83994069,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.972554, 40.764898],
#        [-73.962675, 40.760718],
#        [-73.96162, 40.760095],
#        [-73.961521, 40.760231],
#        [-73.958516, 40.758932],
#        [-73.959167, 40.758024],
#        [-73.95906, 40.757969],
#        [-73.960763, 40.755707],
#        [-73.961639, 40.755156],
#        [-73.963202, 40.753368],
#        [-73.963444, 40.75349],
#        [-73.964595, 40.75244],
#        [-73.966492, 40.7531],
#        [-73.977655, 40.757911],
#        [-73.972554, 40.764898]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Manhattan',
#     'cartodb_id': 239,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10022',
#     'objectid': 239,
#     'po_name': 'New York',
#     'postalcode': '10022',
#     'shape_area': 12728335.6232,
#     'shape_leng': 14672.45315,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-74.007084, 40.70387],
#        [-74.0075, 40.704222],
#        [-74.006905, 40.704629],
#        [-74.006489, 40.704277],
#        [-74.007084, 40.70387]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 240,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10043',
#     'objectid': 240,
#     'po_name': 'New York',
#     'postalcode': '10043',
#     'shape_area': 38262.3648074,
#     'shape_leng': 788.626538246,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.976314, 40.752505],
#        [-73.976509, 40.752586],
#        [-73.976115, 40.753124],
#        [-73.975245, 40.752756],
#        [-73.975639, 40.752219],
#        [-73.976314, 40.752505]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 206,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10170',
#     'objectid': 206,
#     'po_name': 'New York',
#     'postalcode': '10170',
#     'shape_area': 61793.1751378,
#     'shape_leng': 999.928298243,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.97274, 40.757069],
#        [-73.972566, 40.757308],
#        [-73.972098, 40.757074],
#        [-73.972275, 40.756834],
#        [-73.97274, 40.757069]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 207,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10112',
#     'objectid': 207,
#     'po_name': 'New York',
#     'postalcode': '10112',
#     'shape_area': 16700.7379806,
#     'shape_leng': 521.003076773,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.992099, 40.751774],
#        [-73.991614, 40.752193],
#        [-73.991356, 40.752085],
#        [-73.991611, 40.751569],
#        [-73.992099, 40.751774]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 208,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10122',
#     'objectid': 208,
#     'po_name': 'New York',
#     'postalcode': '10122',
#     'shape_area': 23294.6381032,
#     'shape_leng': 705.234391855,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.982988, 40.766298],
#        [-73.98281, 40.766544],
#        [-73.982038, 40.766218],
#        [-73.982067, 40.766063],
#        [-73.982298, 40.76616],
#        [-73.982382, 40.766044],
#        [-73.982988, 40.766298]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 209,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10107',
#     'objectid': 209,
#     'po_name': 'New York',
#     'postalcode': '10107',
#     'shape_area': 23030.1758969,
#     'shape_leng': 716.959417135,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.97724, 40.760552],
#        [-73.976991, 40.760814],
#        [-73.976039, 40.760412],
#        [-73.976396, 40.759923],
#        [-73.977391, 40.760343],
#        [-73.97724, 40.760552]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 210,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10103',
#     'objectid': 210,
#     'po_name': 'New York',
#     'postalcode': '10103',
#     'shape_area': 62713.2534062,
#     'shape_leng': 1038.49399077,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-74.008715, 40.70749],
#        [-74.009489, 40.707991],
#        [-74.009238, 40.708215],
#        [-74.008465, 40.707715],
#        [-74.008715, 40.70749]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 241,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10081',
#     'objectid': 241,
#     'po_name': 'New York',
#     'postalcode': '10081',
#     'shape_area': 30240.5054524,
#     'shape_leng': 777.935098182,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-74.084117, 40.634776],
#        [-74.082313, 40.633663],
#        [-74.080455, 40.635497],
#        [-74.080259, 40.635862],
#        [-74.079586, 40.636173],
#        [-74.078796, 40.636974],
#        [-74.079885, 40.633405],
#        [-74.078992, 40.633193],
#        [-74.079088, 40.632886],
#        [-74.075959, 40.631969],
#        [-74.076535, 40.63095],
#        [-74.076749, 40.630222],
#        [-74.076568, 40.629609],
#        [-74.074707, 40.629796],
#        [-74.074826, 40.631342],
#        [-74.07412, 40.632941],
#        [-74.074142, 40.634393],
#        [-74.073314, 40.634841],
#        [-74.07339, 40.635791],
#        [-74.073147, 40.635812],
#        [-74.072832, 40.633666],
#        [-74.073328, 40.632058],
#        [-74.072985, 40.630309],
#        [-74.072775, 40.630242],
#        [-74.072921, 40.629967],
#        [-74.072292, 40.627152],
#        [-74.072713, 40.627068],
#        [-74.072176, 40.624622],
#        [-74.069762, 40.621295],
#        [-74.066199, 40.618722],
#        [-74.065573, 40.619275],
#        [-74.065446, 40.619203],
#        [-74.066682, 40.618068],
#        [-74.066422, 40.617877],
#        [-74.06605, 40.618195],
#        [-74.065702, 40.617958],
#        [-74.065448, 40.6181],
#        [-74.065139, 40.617891],
#        [-74.065148, 40.617544],
#        [-74.064198, 40.616901],
#        [-74.063813, 40.61683],
#        [-74.063612, 40.61655],
#        [-74.063953, 40.61634],
#        [-74.066333, 40.617379],
#        [-74.070954, 40.620432],
#        [-74.071847, 40.61861],
#        [-74.073321, 40.617874],
#        [-74.073043, 40.617516],
#        [-74.074395, 40.616909],
#        [-74.075434, 40.61578],
#        [-74.079439, 40.608568],
#        [-74.081451, 40.60631],
#        [-74.085061, 40.601559],
#        [-74.087248, 40.596311],
#        [-74.087518, 40.595995],
#        [-74.087675, 40.596008],
#        [-74.088434, 40.594802],
#        [-74.091217, 40.592234],
#        [-74.091577, 40.59242],
#        [-74.09225, 40.591937],
#        [-74.097196, 40.588303],
#        [-74.09692, 40.588162],
#        [-74.101789, 40.584618],
#        [-74.102008, 40.584801],
#        [-74.101639, 40.58515],
#        [-74.100686, 40.587156],
#        [-74.100193, 40.587764],
#        [-74.10208, 40.588742],
#        [-74.1048, 40.586285],
#        [-74.109248, 40.582678],
#        [-74.111174, 40.581849],
#        [-74.113169, 40.5807],
#        [-74.115642, 40.57847],
#        [-74.116875, 40.578258],
#        [-74.117569, 40.577714],
#        [-74.117831, 40.577827],
#        [-74.118277, 40.578145],
#        [-74.118944, 40.580455],
#        [-74.12325, 40.585117],
#        [-74.1154, 40.596166],
#        [-74.114792, 40.596595],
#        [-74.111321, 40.597552],
#        [-74.111302, 40.598171],
#        [-74.11191, 40.598672],
#        [-74.113383, 40.600571],
#        [-74.10987, 40.601511],
#        [-74.108291, 40.601716],
#        [-74.101913, 40.601073],
#        [-74.100493, 40.601532],
#        [-74.100642, 40.602012],
#        [-74.100116, 40.602311],
#        [-74.09958, 40.602903],
#        [-74.100233, 40.603044],
#        [-74.100467, 40.60327],
#        [-74.100559, 40.603807],
#        [-74.100362, 40.604026],
#        [-74.099593, 40.604034],
#        [-74.099233, 40.603851],
#        [-74.099157, 40.603111],
#        [-74.098032, 40.603098],
#        [-74.096559, 40.603529],
#        [-74.095782, 40.603448],
#        [-74.095019, 40.603588],
#        [-74.094838, 40.604271],
#        [-74.093505, 40.604127],
#        [-74.093514, 40.604491],
#        [-74.0939, 40.604509],
#        [-74.093948, 40.604763],
#        [-74.094308, 40.604804],
#        [-74.094581, 40.605714],
#        [-74.094891, 40.605616],
#        [-74.095204, 40.605811],
#        [-74.094896, 40.606676],
#        [-74.095379, 40.607136],
#        [-74.096617, 40.606377],
#        [-74.097003, 40.605789],
#        [-74.097474, 40.605727],
#        [-74.096969, 40.606992],
#        [-74.096305, 40.607512],
#        [-74.096709, 40.608035],
#        [-74.096687, 40.608283],
#        [-74.096026, 40.608534],
#        [-74.096264, 40.608874],
#        [-74.09494, 40.609305],
#        [-74.095027, 40.609455],
#        [-74.095469, 40.60953],
#        [-74.097116, 40.609231],
#        [-74.097422, 40.610261],
#        [-74.098104, 40.61096],
#        [-74.095919, 40.611],
#        [-74.09431, 40.610814],
#        [-74.092844, 40.610448],
#        [-74.09084, 40.609689],
#        [-74.089932, 40.611051],
#        [-74.09063, 40.611339],
#        [-74.090189, 40.611947],
#        [-74.089732, 40.612095],
#        [-74.089732, 40.612285],
#        [-74.088662, 40.613693],
#        [-74.090321, 40.614179],
#        [-74.090141, 40.614835],
#        [-74.094302, 40.616656],
#        [-74.094071, 40.617704],
#        [-74.093387, 40.61831],
#        [-74.092784, 40.618259],
#        [-74.090982, 40.617158],
#        [-74.087413, 40.615929],
#        [-74.086592, 40.617127],
#        [-74.086171, 40.618074],
#        [-74.086041, 40.61882],
#        [-74.08667, 40.618973],
#        [-74.086783, 40.618434],
#        [-74.087612, 40.618494],
#        [-74.087516, 40.619065],
#        [-74.088683, 40.619599],
#        [-74.088731, 40.619844],
#        [-74.08942, 40.620307],
#        [-74.088684, 40.620998],
#        [-74.088515, 40.622966],
#        [-74.088914, 40.627729],
#        [-74.088508, 40.628919],
#        [-74.086822, 40.630318],
#        [-74.088078, 40.631081],
#        [-74.085749, 40.633956],
#        [-74.085201, 40.633762],
#        [-74.084117, 40.634776]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Staten Island',
#     'cartodb_id': 171,
#     'cty_fips': '085',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10304',
#     'objectid': 171,
#     'po_name': 'Staten Island',
#     'postalcode': '10304',
#     'shape_area': 98226679.797,
#     'shape_leng': 85662.2596497,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.976691, 40.754564],
#        [-73.976475, 40.754862],
#        [-73.975386, 40.754404],
#        [-73.975737, 40.753923],
#        [-73.976825, 40.754382],
#        [-73.976691, 40.754564]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 214,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10169',
#     'objectid': 214,
#     'po_name': 'New York',
#     'postalcode': '10169',
#     'shape_area': 66246.3463652,
#     'shape_leng': 1112.84879736,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.974675, 40.754295],
#        [-73.975534, 40.754652],
#        [-73.975185, 40.755131],
#        [-73.973899, 40.7546],
#        [-73.974255, 40.754121],
#        [-73.974675, 40.754295]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 215,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10167',
#     'objectid': 215,
#     'po_name': 'New York',
#     'postalcode': '10167',
#     'shape_area': 80926.1872511,
#     'shape_leng': 1209.13569938,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.976349, 40.755002],
#        [-73.976, 40.755476],
#        [-73.975608, 40.755315],
#        [-73.975953, 40.754836],
#        [-73.976349, 40.755002]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 216,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10177',
#     'objectid': 216,
#     'po_name': 'New York',
#     'postalcode': '10177',
#     'shape_area': 24688.0511035,
#     'shape_leng': 645.753044366,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.973884, 40.755377],
#        [-73.973466, 40.755205],
#        [-73.973823, 40.754729],
#        [-73.975094, 40.755268],
#        [-73.974752, 40.755734],
#        [-73.973884, 40.755377]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 217,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10172',
#     'objectid': 217,
#     'po_name': 'New York',
#     'postalcode': '10172',
#     'shape_area': 79589.1001039,
#     'shape_leng': 1202.12732775,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-74.120646, 40.641044],
#        [-74.119611, 40.64146],
#        [-74.118288, 40.641545],
#        [-74.117756, 40.641856],
#        [-74.117567, 40.641627],
#        [-74.11716, 40.641679],
#        [-74.117221, 40.641871],
#        [-74.115392, 40.642446],
#        [-74.115119, 40.64279],
#        [-74.113797, 40.64361],
#        [-74.113584, 40.643576],
#        [-74.111208, 40.644989],
#        [-74.108922, 40.645668],
#        [-74.104704, 40.6456],
#        [-74.104137, 40.645781],
#        [-74.103993, 40.645658],
#        [-74.10242, 40.645588],
#        [-74.100605, 40.645132],
#        [-74.098859, 40.645037],
#        [-74.098397, 40.645397],
#        [-74.096546, 40.645365],
#        [-74.094693, 40.645577],
#        [-74.093478, 40.645857],
#        [-74.089939, 40.647213],
#        [-74.089306, 40.647332],
#        [-74.089093, 40.647088],
#        [-74.089773, 40.646714],
#        [-74.089692, 40.646297],
#        [-74.095042, 40.644949],
#        [-74.09793, 40.644667],
#        [-74.100809, 40.644761],
#        [-74.100068, 40.640127],
#        [-74.10481, 40.638977],
#        [-74.103967, 40.6347],
#        [-74.106537, 40.634702],
#        [-74.105723, 40.630772],
#        [-74.10583, 40.630149],
#        [-74.104204, 40.62317],
#        [-74.104574, 40.622842],
#        [-74.106544, 40.621892],
#        [-74.110016, 40.620688],
#        [-74.111534, 40.621604],
#        [-74.11331, 40.623042],
#        [-74.117014, 40.624524],
#        [-74.118235, 40.623813],
#        [-74.118397, 40.623572],
#        [-74.118301, 40.62299],
#        [-74.118711, 40.622261],
#        [-74.119355, 40.621822],
#        [-74.120078, 40.621667],
#        [-74.121625, 40.623036],
#        [-74.122045, 40.624184],
#        [-74.124697, 40.623681],
#        [-74.124742, 40.623955],
#        [-74.132058, 40.623387],
#        [-74.131996, 40.624305],
#        [-74.13014, 40.62995],
#        [-74.130602, 40.631365],
#        [-74.129888, 40.633002],
#        [-74.128946, 40.634437],
#        [-74.128844, 40.636747],
#        [-74.128653, 40.637273],
#        [-74.129187, 40.638671],
#        [-74.129818, 40.639519],
#        [-74.131014, 40.640311],
#        [-74.131563, 40.640356],
#        [-74.131097, 40.641036],
#        [-74.130128, 40.640795],
#        [-74.129307, 40.640337],
#        [-74.12923, 40.640484],
#        [-74.128882, 40.640402],
#        [-74.128782, 40.640223],
#        [-74.127146, 40.640227],
#        [-74.126786, 40.640478],
#        [-74.125463, 40.640155],
#        [-74.124933, 40.640261],
#        [-74.124882, 40.640638],
#        [-74.124763, 40.64031],
#        [-74.124259, 40.640147],
#        [-74.123634, 40.640386],
#        [-74.122773, 40.641363],
#        [-74.121421, 40.641508],
#        [-74.120646, 40.641044]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Staten Island',
#     'cartodb_id': 165,
#     'cty_fips': '085',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10310',
#     'objectid': 165,
#     'po_name': 'Staten Island',
#     'postalcode': '10310',
#     'shape_area': 53463275.0023,
#     'shape_leng': 43885.6232403,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.902941, 40.67084],
#        [-73.902227, 40.668331],
#        [-73.901923, 40.668375],
#        [-73.900722, 40.663779],
#        [-73.900916, 40.663733],
#        [-73.899464, 40.658683],
#        [-73.899823, 40.657291],
#        [-73.900448, 40.657252],
#        [-73.90128, 40.656439],
#        [-73.903173, 40.655302],
#        [-73.910888, 40.65416],
#        [-73.92173, 40.654382],
#        [-73.931538, 40.663237],
#        [-73.903474, 40.675507],
#        [-73.903258, 40.673396],
#        [-73.903617, 40.673344],
#        [-73.902941, 40.67084]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Brooklyn',
#     'cartodb_id': 31,
#     'cty_fips': '047',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/11212',
#     'objectid': 31,
#     'po_name': 'Brooklyn',
#     'postalcode': '11212',
#     'shape_area': 41972104.0712,
#     'shape_leng': 26621.8415776,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-74.139257, 40.640736],
#        [-74.139016, 40.640892],
#        [-74.137576, 40.641001],
#        [-74.137342, 40.641137],
#        [-74.13737, 40.641295],
#        [-74.134499, 40.641885],
#        [-74.133497, 40.641717],
#        [-74.133072, 40.641485],
#        [-74.132403, 40.641704],
#        [-74.131256, 40.641597],
#        [-74.131462, 40.64131],
#        [-74.131097, 40.641036],
#        [-74.131563, 40.640356],
#        [-74.131014, 40.640311],
#        [-74.129818, 40.639519],
#        [-74.129187, 40.638671],
#        [-74.128688, 40.637412],
#        [-74.128946, 40.634437],
#        [-74.129888, 40.633002],
#        [-74.130602, 40.631365],
#        [-74.13014, 40.62995],
#        [-74.132037, 40.624161],
#        [-74.132075, 40.622702],
#        [-74.132556, 40.622899],
#        [-74.133274, 40.622392],
#        [-74.13337, 40.622467],
#        [-74.134016, 40.622156],
#        [-74.13725, 40.62393],
#        [-74.137561, 40.621633],
#        [-74.141617, 40.622165],
#        [-74.142336, 40.616609],
#        [-74.145124, 40.616966],
#        [-74.144585, 40.620667],
#        [-74.146809, 40.620714],
#        [-74.147932, 40.621336],
#        [-74.146913, 40.62215],
#        [-74.14708, 40.622233],
#        [-74.146296, 40.623523],
#        [-74.145801, 40.62479],
#        [-74.145767, 40.624957],
#        [-74.146121, 40.62493],
#        [-74.145458, 40.62705],
#        [-74.145666, 40.630344],
#        [-74.145523, 40.633058],
#        [-74.144908, 40.635313],
#        [-74.1436, 40.638514],
#        [-74.14083, 40.63965],
#        [-74.139084, 40.639708],
#        [-74.139257, 40.640736]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Staten Island',
#     'cartodb_id': 168,
#     'cty_fips': '085',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10302',
#     'objectid': 168,
#     'po_name': 'Staten Island',
#     'postalcode': '10302',
#     'shape_area': 29555323.0234,
#     'shape_leng': 27432.5693758,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.767403, 40.615461],
#        [-73.769653, 40.615639],
#        [-73.770731, 40.615963],
#        [-73.770602, 40.616723],
#        [-73.769171, 40.619053],
#        [-73.768244, 40.620137],
#        [-73.767442, 40.620542],
#        [-73.767114, 40.620515],
#        [-73.766083, 40.615677],
#        [-73.767403, 40.615461]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Queens',
#     'cartodb_id': 175,
#     'cty_fips': '081',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/11096',
#     'objectid': 175,
#     'po_name': 'Inwood',
#     'postalcode': '11096',
#     'shape_area': 1512446.30548,
#     'shape_leng': 5205.04677988,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.844302, 40.689443],
#        [-73.837544, 40.691364],
#        [-73.835519, 40.687247],
#        [-73.835246, 40.687325],
#        [-73.834265, 40.685327],
#        [-73.846801, 40.681835],
#        [-73.853924, 40.679686],
#        [-73.863303, 40.679167],
#        [-73.864101, 40.682373],
#        [-73.866027, 40.681918],
#        [-73.866295, 40.683189],
#        [-73.844302, 40.689443]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Queens',
#     'cartodb_id': 27,
#     'cty_fips': '081',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/11416',
#     'objectid': 27,
#     'po_name': 'Ozone Park',
#     'postalcode': '11416',
#     'shape_area': 18854849.8011,
#     'shape_leng': 21630.6754842,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73
]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Queens',
#     'cartodb_id': 140,
#     'cty_fips': '081',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/11411',
#     'objectid': 140,
#     'po_name': 'Cambria Heights',
#     'postalcode': '11411',
#     'shape_area': 35889597.3838,
#     'shape_leng': 27774.8715266,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.700983, 40.738896],
#        [-73.703087, 40.744547],
#        [-73.702185, 40.744742],
#        [-73.7042, 40.75017],
#        [-73.707131, 40.749583],
#        [-73.708694, 40.748758],
#        [-73.710684, 40.75004],
#        [-73.7075, 40.752692],
#        [-73.704775, 40.75527],
#        [-73.700931, 40.752817],
#        [-73.699744, 40.742393],
#        [-73.699605, 40.739595],
#        [-73.700983, 40.738896]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Queens',
#     'cartodb_id': 3,
#     'cty_fips': '081',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/11040',
#     'objectid': 3,
#     'po_name': 'New Hyde Park',
#     'postalcode': '11040',
#     'shape_area': 6269333.41234,
#     'shape_leng': 15749.1615105,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.983017, 40.754851],
#        [-73.982827, 40.75511],
#        [-73.982171, 40.754778],
#        [-73.982509, 40.754318],
#        [-73.983187, 40.754605],
#        [-73.983017, 40.754851]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 242,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10096',
#     'objectid': 242,
#     'po_name': 'New York',
#     'postalcode': '10096',
#     'shape_area': 42106.1146917,
# ...
#        [-74.20333, 40.555839],
#        [-74.19983, 40.548092],
#        [-74.201071, 40.54781],
#        [-74.201515, 40.547558],
#        [-74.200404, 40.544935],
#        [-74.203064, 40.544261],
#        [-74.198581, 40.53448],
#        [-74.196166, 40.535168],
#        [-74.195931, 40.53489],
#        [-74.195512, 40.534818],
#        [-74.19356, 40.535406],
#        [-74.193009, 40.534326],
#        [-74.195704, 40.533608],
#        [-74.197482, 40.532422],
#        [-74.196084, 40.529912],
#        [-74.19454, 40.53062],
#        [-74.195646, 40.529237],
#        [-74.193175, 40.526019],
#        [-74.187575, 40.516994],
#        [-74.188958, 40.515596],
#        [-74.189132, 40.515269],
#        [-74.188808, 40.515064],
#        [-74.189312, 40.51522],
#        [-74.189641, 40.515064],
#        [-74.191129, 40.513301],
#        [-74.19071, 40.513245],
#        [-74.191778, 40.512446],
#        [-74.193481, 40.510514],
#        [-74.195266, 40.509779],
#        [-74.196071, 40.509762],
#        [-74.196692, 40.509941],
#        [-74.198307, 40.510924],
#        [-74.199737, 40.511417],
#        [-74.199967, 40.511635],
#        [-74.199901, 40.511988],
#        [-74.200324, 40.512813],
#        [-74.204002, 40.512236],
#        [-74.205379, 40.512161],
#        [-74.207411, 40.511743],
#        [-74.208859, 40.511194],
#        [-74.209826, 40.510556],
#        [-74.210498, 40.509808],
#        [-74.210817, 40.50872],
#        [-74.211516, 40.508424],
#        [-74.213531, 40.506397],
#        [-74.213948, 40.506434],
#        [-74.214474, 40.506248],
#        [-74.215418, 40.505645],
#        [-74.217243, 40.503611],
#        [-74.217384, 40.503177],
#        [-74.21784, 40.50321],
#        [-74.218134, 40.502993],
#        [-74.218582, 40.502984],
#        [-74.219587, 40.502604],
#        [-74.221172, 40.502499],
#        [-74.221538, 40.502144],
#        [-74.221894, 40.502417],
#        [-74.222705, 40.502347],
#        [-74.223358, 40.501941],
#        [-74.223867, 40.501907],
#        [-74.225004, 40.501368],
#        [-74.225427, 40.501633],
#        [-74.226818, 40.50204],
#        [-74.228142, 40.502024],
#        [-74.231182, 40.510896],
#        [-74.232602, 40.515839],
#        [-74.232827, 40.516377],
#        [-74.233973, 40.517117],
#        [-74.234365, 40.517619],
#        [-74.235112, 40.520917],
#        [-74.24314, 40.521617],
#        [-74.242746, 40.522268],
#        [-74.242978, 40.52388],
#        [-74.24343, 40.52472],
#        [-74.243904, 40.524871],
#        [-74.244021, 40.525052],
#        [-74.243147, 40.526999],
#        [-74.243016, 40.52824],
#        [-74.242757, 40.528466],
#        [-74.242548, 40.528993],
#        [-74.243286, 40.529086],
#        [-74.244023, 40.530181],
#        [-74.242122, 40.530102],
#        [-74.241626, 40.530951],
#        [-74.241811, 40.532563],
#        [-74.242178, 40.532576],
#        [-74.24233, 40.532971],
#        [-74.242324, 40.53334],
#        [-74.24202, 40.533606],
#        [-74.242101, 40.534239],
#        [-74.242925, 40.535359],
#        [-74.243756, 40.5361],
#        [-74.244785, 40.536244],
#        [-74.244052, 40.536415],
#        [-74.244259, 40.536702],
#        [-74.244662, 40.536862],
#        [-74.244939, 40.536651],
#        [-74.245349, 40.536824],
#        [-74.245372, 40.53706],
#        [-74.244904, 40.5373],
#        [-74.244501, 40.537829],
#        [-74.244471, 40.538172],
#        [-74.245278, 40.539158],
#        [-74.245549, 40.540677],
#        [-74.246105, 40.541336],
#        [-74.246327, 40.541921],
#        [-74.247689, 40.543125],
#        [-74.248023, 40.543107],
#        [-74.246197, 40.545654],
#        [-74.243633, 40.547667],
#        [-74.242862, 40.547108],
#        [-74.241666, 40.547141],
#        [-74.239732, 40.5482],
#        [-74.238863, 40.549038],
#        [-74.238436, 40.549151],
#        [-74.237588, 40.55022],
#        [-74.236458, 40.550474],
#        [-74.236409, 40.550635],
#        [-74.236885, 40.551394],
#        [-74.236367, 40.550625],
#        [-74.236176, 40.551451],
#        [-74.23659, 40.551958],
#        [-74.23637, 40.55236],
#        [-74.234899, 40.553005],
#        [-74.23351, 40.552465],
#        [-74.232703, 40.552924],
#        [-74.232092, 40.553766],
#        [-74.232192, 40.553849],
#        [-74.232617, 40.553627],
#        [-74.232416, 40.554279],
#        [-74.231687, 40.555059],
#        [-74.230908, 40.555428],
#        [-74.230457, 40.556045],
#        [-74.230012, 40.555859],
#        [-74.229285, 40.555957],
#        [-74.228894, 40.556283],
#        [-74.228223, 40.556434],
#        [-74.226586, 40.556209],
#        [-74.226229, 40.556309],
#        [-74.223233, 40.555805],
#        [-74.222706, 40.555474],
#        [-74.22192, 40.555443],
#        [-74.221537, 40.555644],
#        [-74.221347, 40.555359],
#        [-74.220868, 40.55594],
#        [-74.220529, 40.555867],
#        [-74.220184, 40.555426],
#        [-74.220135, 40.555067],
#        [-74.219911, 40.554992],
#        [-74.219591, 40.555074],
#        [-74.219548, 40.555292],
#        [-74.219259, 40.555387],
#        [-74.218975, 40.555784],
#        [-74.218308, 40.555916],
#        [-74.217941, 40.555772],
#        [-74.217615, 40.555084],
#        [-74.217482, 40.555073],
#        [-74.216537, 40.555397],
#        [-74.216488, 40.556038],
#        [-74.216155, 40.555976],
#        [-74.215741, 40.556217],
#        [-74.215227, 40.556227],
#        [-74.215155, 40.556623],
#        [-74.214742, 40.557034],
#        [-74.214904, 40.557451],
#        [-74.213966, 40.557951],
#        [-74.21383, 40.558624],
#        [-74.213121, 40.558608]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Staten Island',
#     'cartodb_id': 192,
#     'cty_fips': '085',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10309',
#     'objectid': 192,
#     'po_name': 'Staten Island',
#     'postalcode': '10309',
#     'shape_area': 215835793.513,
#     'shape_leng': 79038.5334731,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-74.249666, 40.515555],
#        [-74.248231, 40.516481],
#        [-74.248108, 40.516365],
#        [-74.24661, 40.516368],
#        [-74.246698, 40.516569],
#        [-74.245224, 40.517296],
#        [-74.245739, 40.51802],
#        [-74.245522, 40.518138],
#        [-74.244988, 40.518163],
#        [-74.244333, 40.518618],
#        [-74.243748, 40.518338],
#        [-74.242456, 40.518316],
#        [-74.242009, 40.518557],
#        [-74.242007, 40.518834],
#        [-74.241275, 40.519167],
#        [-74.241054, 40.51956],
#        [-74.240821, 40.519546],
#        [-74.240568, 40.519193],
#        [-74.239919, 40.520047],
#        [-74.240047, 40.52024],
#        [-74.240596, 40.520312],
#        [-74.24109, 40.520653],
#        [-74.241142, 40.520873],
#        [-74.241674, 40.520828],
#        [-74.24317, 40.521167],
#        [-74.24314, 40.521617],
#        [-74.235112, 40.520917],
#        [-74.234365, 40.517619],
#        [-74.233973, 40.517117],
#        [-74.232827, 40.516377],
#        [-74.232602, 40.515839],
#        [-74.231182, 40.510896],
#        [-74.228142, 40.502024],
#        [-74.229186, 40.502025],
#        [-74.230283, 40.501728],
#        [-74.231619, 40.501648],
#        [-74.23247, 40.50131],
#        [-74.233264, 40.500761],
#        [-74.2338, 40.500725],
#        [-74.233633, 40.500562],
#        [-74.234391, 40.500679],
#        [-74.235377, 40.50049],
#        [-74.23627, 40.49997],
#        [-74.236864, 40.499867],
#        [-74.237639, 40.499006],
#        [-74.238104, 40.49896],
#        [-74.239902, 40.497429],
#        [-74.241743, 40.497464],
#        [-74.242199, 40.497287],
#        [-74.242792, 40.497485],
#        [-74.244365, 40.497187],
#        [-74.244785, 40.497265],
#        [-74.244773, 40.497121],
#        [-74.245213, 40.496788],
#        [-74.245697, 40.496688],
#        [-74.246183, 40.496087],
#        [-74.247074, 40.49584],
#        [-74.248651, 40.496146],
#        [-74.249447, 40.496505],
#        [-74.250188, 40.497135],
#        [-74.250323, 40.497661],
#        [-74.250117, 40.498052],
#        [-74.250423, 40.498428],
#        [-74.251394, 40.499],
#        [-74.251738, 40.498926],
#        [-74.252746, 40.49942],
#        [-74.253342, 40.500085],
#        [-74.253702, 40.501075],
#        [-74.254429, 40.502128],
#        [-74.255386, 40.503984],
#        [-74.255486, 40.504704],
#        [-74.255384, 40.50661],
#        [-74.255757, 40.507699],
#        [-74.255408, 40.508299],
#        [-74.254298, 40.50889],
#        [-74.253443, 40.509842],
#        [-74.253159, 40.511087],
#        [-74.253151, 40.512256],
#        [-74.252123, 40.512842],
#        [-74.251992, 40.513231],
#        [-74.252235, 40.513667],
#        [-74.251927, 40.514225],
#        [-74.251561, 40.514192],
#        [-74.251397, 40.514439],
#        [-74.250434, 40.514814],
#        [-74.250055, 40.515177],
#        [-74.250187, 40.515325],
#        [-74.249862, 40.515506],
#        [-74.249365, 40.515008],
#        [-74.249229, 40.515089],
#        [-74.249666, 40.515555]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Staten Island',
#     'cartodb_id': 193,
#     'cty_fips': '085',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10307',
#     'objectid': 193,
#     'po_name': 'Staten Island',
#     'postalcode': '10307',
#     'shape_area': 46028382.6284,
#     'shape_leng': 31375.3132189,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-74.016639, 40.712168],
#        [-74.015676, 40.711805],
#        [-74.01638, 40.710082],
#        [-74.014683, 40.709797],
#        [-74.016416, 40.705219],
#        [-74.01649, 40.704307],
#        [-74.017251, 40.703868],
#        [-74.017679, 40.703894],
#        [-74.017491, 40.704679],
#        [-74.018112, 40.704546],
#        [-74.018917, 40.704747],
#        [-74.01935, 40.706097],
#        [-74.019126, 40.706987],
#        [-74.018584, 40.706872],
#        [-74.018184, 40.707845],
#        [-74.018862, 40.708043],
#        [-74.017871, 40.712362],
#        [-74.016639, 40.712168]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Manhattan',
#     'cartodb_id': 194,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10280',
#     'objectid': 194,
#     'po_name': 'New York',
#     'postalcode': '10280',
#     'shape_area': 2234113.99487,
#     'shape_leng': 8192.12492629,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-74.01441, 40.710992],
#        [-74.013754, 40.713691],
#        [-74.010153, 40.712064],
#        [-74.011674, 40.709687],
#        [-74.01441, 40.710992]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 0,
#     'borough': 'Manhattan',
#     'cartodb_id': 195,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10048',
#     'objectid': 195,
#     'po_name': 'New York',
#     'postalcode': '10048',
#     'shape_area': 972788.42696,
#     'shape_leng': 4033.60069883,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-74.008644, 40.7126],
#        [-74.008506, 40.712778],
#        [-74.007913, 40.71251],
#        [-74.00821, 40.712157],
#        [-74.008782, 40.71242],
#        [-74.008644, 40.7126]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 196,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10279',
#     'objectid': 196,
#     'po_name': 'New York',
#     'postalcode': '10279',
#     'shape_area': 28664.7058134,
#     'shape_leng': 680.943500465,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.979185, 40.752139],
#        [-73.979498, 40.752269],
#        [-73.979415, 40.752384],
#        [-73.979098, 40.75226],
#        [-73.978873, 40.752465],
#        [-73.978297, 40.752233],
#        [-73.978635, 40.75177],
#        [-73.979204, 40.752002],
#        [-73.979185, 40.752139]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 197,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10165',
#     'objectid': 197,
#     'po_name': 'New York',
#     'postalcode': '10165',
#     'shape_area': 40779.8152022,
#     'shape_leng': 985.263293999,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.977031, 40.7513],
#        [-73.976868, 40.751233],
#        [-73.97665, 40.751534],
#        [-73.97626, 40.751372],
#        [-73.9766, 40.750899],
#        [-73.977153, 40.751134],
#        [-73.977031, 40.7513]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 198,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10168',
#     'objectid': 198,
#     'po_name': 'New York',
#     'postalcode': '10168',
#     'shape_area': 27810.1220594,
#     'shape_leng': 742.127233302,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.974075, 40.759256],
#        [-73.973895, 40.759507],
#        [-73.973204, 40.759211],
#        [-73.973555, 40.758729],
#        [-73.974027, 40.758931],
#        [-73.973854, 40.759169],
#        [-73.974075, 40.759256]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 199,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10055',
#     'objectid': 199,
#     'po_name': 'New York',
#     'postalcode': '10055',
#     'shape_area': 37223.5387892,
#     'shape_leng': 842.265584049,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.979243, 40.762827],
#        [-73.97953, 40.762948],
#        [-73.979248, 40.763336],
#        [-73.978575, 40.763053],
#        [-73.978859, 40.762665],
#        [-73.979243, 40.762827]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 200,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10105',
#     'objectid': 200,
#     'po_name': 'New York',
#     'postalcode': '10105',
#     'shape_area': 35422.1567546,
#     'shape_leng': 769.015785846,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.986732, 40.748571],
#        [-73.986554, 40.74881],
#        [-73.986326, 40.748718],
#        [-73.98616, 40.748957],
#        [-73.98481, 40.748396],
#        [-73.985147, 40.74792],
#        [-73.986732, 40.748571]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 201,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10118',
#     'objectid': 201,
#     'po_name': 'New York',
#     'postalcode': '10118',
#     'shape_area': 91733.7153701,
#     'shape_leng': 1392.54638041,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.978695, 40.755496],
#        [-73.978479, 40.755407],
#        [-73.978654, 40.755166],
#        [-73.979269, 40.755432],
#        [-73.979135, 40.755615],
#        [-73.978695, 40.755496]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 202,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10176',
#     'objectid': 202,
#     'po_name': 'New York',
#     'postalcode': '10176',
#     'shape_area': 18289.0897346,
#     'shape_leng': 590.377332961,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-73.951328, 40.76931],
#        [-73.951652, 40.769446],
#        [-73.951299, 40.769947],
#        [-73.950979, 40.769814],
#        [-73.951328, 40.76931]]]],
#     'type': 'MultiPolygon'},
#    'properties': {'bldgpostalcode': 1,
#     'borough': 'Manhattan',
#     'cartodb_id': 203,
#     'cty_fips': '061',
#     'id': 'http://nyc.pediacities.com/Resource/PostalCode/10162',
#     'objectid': 203,
#     'po_name': 'New York',
#     'postalcode': '10162',
#     'shape_area': 21034.8869204,
#     'shape_leng': 624.792615306,
#     'st_fips': '36',
#     'state': 'NY'},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}

# %%
data = newyork_data['features']
df = json_normalize(data)
df.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#       type  ...                                      properties.id
# 0  Feature  ...  http://nyc.pediacities.com/Resource/PostalCode...
# 1  Feature  ...  http://nyc.pediacities.com/Resource/PostalCode...
# 2  Feature  ...  http://nyc.pediacities.com/Resource/PostalCode...
# 3  Feature  ...  http://nyc.pediacities.com/Resource/PostalCode...
# 4  Feature  ...  http://nyc.pediacities.com/Resource/PostalCode...
#
# [5 rows x 15 columns]

# %% [markdown]
# Conduct exploratory data analysis to count how many salad shops are in each zip code

# %%
df2= df[['properties.postalcode']]
df2.columns=['Zip Code']
df2['Contains Salad Place']=0
df2.head(10)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   Zip Code  Contains Salad Place
# 0    11693                     0
# 1    10463                     0
# 2    10033                     0
# 3    11367                     0
# 4    10472                     0
# 5    10037                     0
# 6    10026                     0
# 7    10119                     0
# 8    10044                     0
# 9    10036                     0

# %%
all_zip_codes=df['properties.postalcode'].tolist()
zip_with_salad=salad_joints['Zip Code'].tolist()
print("There are {} zip codes total!".format(str(len(all_zip_codes))))
# Out:
# There are 262 zip codes total!

# %%
from collections import Counter
Count=Counter(zip_with_salad)

# %%
for x in range(0,len(all_zip_codes)):
   if df2['Zip Code'][x] in zip_with_salad:
     df2['Contains Salad Place'][x]=Count[df2['Zip Code'][x]]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2882: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df2.head(50)
# Out:
#    Zip Code  Contains Salad Place
# 0     11693                     0
# 1     10463                     0
# 2     10033                     0
# 3     11367                     0
# 4     10472                     0
# 5     10037                     0
# 6     10026                     0
# 7     10119                     0
# 8     10044                     0
# 9     10036                     1
# 10    10002                     0
# 11    10038                     0
# 12    11206                     0
# 13    10275                     0
# 14    10111                     0
# 15    10022                     0
# 16    10043                     0
# 17    10170                     0
# 18    10112                     0
# 19    10122                     0
# 20    10107                     0
# 21    10103                     0
# 22    10081                     0
# 23    10304                     0
# 24    10169                     0
# 25    10167                     0
# 26    10177                     0
# 27    10172                     0
# 28    10310                     0
# 29    11212                     0
# 30    10302                     0
# 31    11096                     0
# 32    11416                     0
# 33    10470                     0
# 34    10469                     0
# 35    10039                     0
# 36    10029                     0
# 37    10010                     2
# 38    11411                     0
# 39    11040                     0
# 40    10096                     0
# 41    11220                     0
# 42    11225                     0
# 43    11209                     0
# 44    11228                     0
# 45    11372                     0
# 46    11004                     0
# 47    10305                     0
# 48    11096                     0
# 49    11223                     0

# %%
print(max(df2['Contains Salad Place']))
# Out:
# 5

# %% [markdown]
# Create a heat map with our data

# %%
world_geo = r'/content/nyc_zip_code_tabulation_areas_polygons.geojson' # geojson file

    # create a plain world map
world_map = folium.Map(location=[40.693943, -73.985880], zoom_start=12, tiles='Mapbox Bright')

# generate choropleth map using the total immigration of each country to Canada from 1980 to 2013
folium.Choropleth(
    geo_data=world_geo,
    data=df2,
    columns=['Zip Code', 'Contains Salad Place'],
    key_on='feature.properties.postalcode',
    fill_color='YlOrRd', 
    fill_opacity=0.7, 
    line_opacity=0.2,
    legend_name='Number of Salad Places Per Neighborhood'
).add_to(world_map)

# display map

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Find which zip codes have the fewest salad shops

# %%
sorted(Count.items(), key=lambda kv: kv[1], reverse=False)
# Out:
# [('10573', 1),
#  ('11211', 1),
#  ('10065', 1),
#  ('11105', 1),
#  ('10009', 1),
#  ('10021', 1),
#  ('11217', 1),
#  ('11553', 1),
#  ('10024', 1),
#  ('11238', 1),
#  ('11215', 1),
#  ('10075', 1),
#  ('10018', 1),
#  ('10036', 1),
#  ('10025', 2),
#  ('10005', 2),
#  ('10011', 2),
#  ('10012', 2),
#  ('11201', 2),
#  ('10010', 2),
#  ('10028', 2),
#  ('10016', 3),
#  ('10023', 3),
#  ('10001', 3),
#  ('10014', 3),
#  ('10003', 5),
#  ('10019', 5)]

# %% [markdown]
# ##Results
# Our results showed that the zip codes 10573, 11211, 10065, 11105, 10009, 10021, 11217, 11553, 10024, 11238, 11215, 10075, 10018, 10036 all only contain a single salad shop.
#
# Our results also showed that the zip codes 10003, 10019 in Gramercy Park and West Midtown both have 5 salad shops each. These are the most of any zip code we looked at.

# %% [markdown]
# ##Obervations
# Our results showed that the densest concentrations of salad shops are below central park in midtown Manhattan. The areas with the sparsest concentration of salad shops are lower Manhattan, around the financial districts and the lower east and west sides.

# %% [markdown]
# ##Conclusion
#
# In conclusion, I would advise looking further into opening a salad shop in lower Manhattan. This area has the sparsest amount of salad shops. It is also a highly populated area of the city where there are a lot of office buildings where people may be interested in getting a salad for lunch.
